# %% [markdown]
# <a href="https://colab.research.google.com/github/YuroLim/Python-Study/blob/main/%EC%82%B0%ED%94%843%EC%A3%BC%EC%B0%A8%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
j = '040823-3124565'



age = j[0:2]

age_int = int(age)

age_fin = 26 - age_int

print("your age is", age_fin, ".")
# Out:
# your age is 22 .

# %%
j = '970823-3124565'


part_age = j[0:1]
part_age_int = int(part_age)

if part_age_int == 9 :
    age = j[0:2]
    age_int = int(age)
    age_fin = 126 - age_int
    print("your age is", age_fin, ".")

else :
    age = j[0:2]
    age_int = int(age)
    age_fin = 26 - age_int
    print("your age is", age_fin, ".")

# %%
j = '970823-3124565'


if int(j[7]) < 3 :
    age = 26 - int(j[0:2])
else :
    age = 100 - int(j[0:2]) +26

print("your age is" + str(age))

# %%
s1 = 'hello dgu'
s2= 'are you'

for c1 in s1 :
    for c2 in s2 :
        if c1 == c2 :
            print(c1, c2, 'same!!')
            break
