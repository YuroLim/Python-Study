# %% [markdown]
# <a href="https://colab.research.google.com/github/YuroLim/Python-Study/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hi = "hello there"
name = "ana"
greet = hi + name
greeting = hi + "" + name

silly = hi + "" + name * 3

print(silly)
# Out:
# hello thereanaanaana

# %% [markdown]
# x = 1
# print(x)
# x_str = str(x)
# print("my fav num is", x, ".", "x=", x)
# print("my fav num is", x_str + "." + "x=" + x_str)

# %%
text = input("Type anything..")
print(5*text)
# Out:
# Type anything..yuro
# yuroyuroyuroyuroyuro

# %%
num = int(input("Type a numper.."))
print(5*num)
# Out:
# Type a numper..3
# 15

# %%
pset_time = 15
sleep_time = 8
print(sleep_time > pset_time)
derive = True
drink = False
both = drink and derive
print(both)
# Out:
# False
# False

# %%
pset_time = 15
sleep_time = 8
print("sleep_time",  ">",  "pset_time")
# Out:
# sleep_time > pset_time

# %%
pset_time = 15
sleep_time = 8
print(sleep_time, ">", pset_time)
# Out:
# 8 > 15

# %%
derive = True
drink = False
both = drink, "and", derive
print(both)
# Out:
# (False, 'and', True)

# %%
derive = True
dirnk = False
print(drink, "and", derive)
# Out:
# False and True

# %%
derive = True
drink = False
both = drink and derive
print(both)
# Out:
#   File "/tmp/ipykernel_6718/2040698224.py", line 3
#     both = drink, and, derive
#                   ^
# SyntaxError: invalid syntax

# %%
derive = True
drink = False
both = drink and derive
print(both)
# Out:
# False

# %%
x = float(input("Enter a number for x:"))
y = float(input("Enter a number for y:"))
if x == y:
  print("x and y are equal")
  if y != 0:
    print("therefore, x/y is", x/y)
elif x < y:
  print("x is smaller")
else:
  print("y is smaller")
print("thanks!")
# Out:
# Enter a number for x:9
# Enter a number for y:3
# y is smaller
# thanks!

# %%
n = input("You're in the Lost Forest. Go left or right?")
while n == "right":
  n = input("You're in the Lost Forest. Go left or right?")
print("You got out of the Lost Forest!")
# Out:
# You're in the Lost Forest. Go left or right?right
# You're in the Lost Forest. Go left or right?left
# You got out of the Lost Forest!

# %%
mysum = 0
for i in range(7, 10):
  mysum += i
print(mysum)
# Out:
# 24

# %%
mysum = 0
for i in range(5, 11, 2):
  mysum += i
print(mysum)
# Out:
# 21

# %%
mysum = 0
for i in range(5, 11, 2) :
  mysum += i
  if mysum == 5 :
      break
      mysum += 1
print(mysum)
# Out:
# 5
